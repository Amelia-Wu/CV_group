# %%
from myModel.VGG16_cos_baseline import *

# %%
# extract features from right images
# test_right_path is the path to the folder containing the right images in the test set
# right_features_saving_path is the path to the file where the features will be saved
test_right_path = './dataset/test/right'
right_features_saving_path = f'./dataset/test/right_features_{target_size[0]}_{target_size[1]}.npz'

extractor = VggFeatureExtractor()
extractor.save_features(test_right_path, right_features_saving_path)
# Out:
# ...
# 1/1 [==============================] - 0s 110ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       5 right_features_saving_path = f'./dataset/test/right_features_{target_size[0]}_{target_size[1]}.npz'
#       7 extractor = VggFeatureExtractor()
# ----> 8 extractor.save_features(test_right_path, right_features_saving_path)
#
# File ~/Documents/GitHub/CV_group/myModel/VGG16_cos_baseline.py:46, in VggFeatureExtractor.save_features(self, directory, output_file)
#      44 for filename in os.listdir(directory):
#      45     if filename.endswith('.jpg') or filename.endswith('.png'):
# ---> 46         feature = self.extract(os.path.join(directory, filename))
#      47         feature_list.append(feature)
#      48         filenames.append(filename)
#
# ...

# %%
# extract features from left images
# test_left_path is the path to the folder containing the left images in the test set
# left_features_saving_path is the path to the file where the features will be saved
test_left_path = './dataset/test/left'
left_features_saving_path = f'./dataset/test/left_features_{target_size[0]}_{target_size[1]}.npz'
extractor.save_features(test_left_path, left_features_saving_path)

# %%
test_candidates_path = './dataset/test_candidates.csv'
submission_output_path = './dataset/test_baseline_submission.csv'

compute_cosine_similarity_for_submission( test_candidates_path,
                                          left_features_saving_path,
                                          right_features_saving_path,
                                          submission_output_path)
